# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %% [markdown]
# # steps
#
# 1. preprocess + EDA + feature selection
# 2. extract input n output cols
# 3. scale the values
# 4. train test split
# 5. train the model
# 6. evaluate the model/model selection
# 7. deploy the model

# %% [markdown]
# ## loading DATASET

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df = df.iloc[:,-3:]

# %% [markdown]
# ## preprocessing

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %% [markdown]
# ##EDA

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'], df['iq'], c=df['placement'])

plt.show()

# %% [markdown]
# ##Extract input n output columns

# %%
X = df.iloc[:,0:-1]
Y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %% [markdown]
# ##train test split

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_train
# Out:
#     cgpa     iq
# 92   5.2  110.0
# 24   4.7  121.0
# 22   4.9  120.0
# 46   5.3  114.0
# 9    5.1   66.0
# ..   ...    ...
# 97   6.7  182.0
# 23   4.7   87.0
# 71   6.1  132.0
# 69   8.5  120.0
# 66   6.9   96.0
#
# [80 rows x 2 columns]

# %%
X_test
# Out:
#     cgpa     iq
# 58   8.0   79.0
# 6    5.7  143.0
# 0    6.8  123.0
# 80   4.9  196.0
# 12   5.4  139.0
# 89   4.9  151.0
# 85   5.8  166.0
# 52   7.0  175.0
# 82   6.5   37.0
# 44   7.5   61.0
# 28   5.2   90.0
# 95   4.3  200.0
# 74   6.7  154.0
# 79   6.5   90.0
# 59   4.8  112.0
# 76   4.9  155.0
# 68   4.0   75.0
# 43   6.8  141.0
# 53   8.3  168.0
# 47   5.2  161.0

# %% [markdown]
# ##scale the values

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_
#        [-7.11054635e-01,  2.67233270e+00],
#        [-1.76929088e-01,  5.28715371e-01],
#        [-2.40245220e+00,  1.60052403e+00],
#        [ 1.11276156e-03,  5.81652263e-02],
#        [ 1.87055218e+00,  7.11707094e-01],
#        [ 1.79154611e-01, -2.29393196e-01],
#        [-1.42322203e+00, -2.08545210e+00],
#        [-7.11054635e-01,  2.67298624e-01],
#        [ 7.13280158e-01, -8.30651714e-01],
#        [-8.00075560e-01,  1.41753231e+00],
#        [ 1.87055218e+00,  1.15611556e+00],
#        [ 1.11276156e-03, -2.00702708e+00],
#        [ 2.68175535e-01,  1.36590250e-01],
#        [-2.22441035e+00,  2.90760777e+00],
#        [ 8.02301083e-01,  4.24148672e-01],
#        [ 9.01336862e-02, -1.06592679e+00],
#        [ 6.24259234e-01,  1.57438236e+00],
#        [-1.15615926e+00, -9.09076738e-01],
#        [ 9.01336862e-02,  2.67298624e-01],
#        [ 2.22663588e+00, -4.64014726e-02],
#        [ 8.02301083e-01, -6.73801666e-01]])

# %%
X_test
# Out:
# array([[ 1.78153125, -1.11821014],
#        [-0.26595001,  0.55485705],
#        [ 0.71328016,  0.03202355],
#        [-0.97811741,  1.94036581],
#        [-0.53301279,  0.45029035],
#        [-0.97811741,  0.76399044],
#        [-0.17692909,  1.15611556],
#        [ 0.89132201,  1.39139064],
#        [ 0.44621738, -2.21616047],
#        [ 1.33642663, -1.58876028],
#        [-0.71105464, -0.83065171],
#        [-1.51224296,  2.04493251],
#        [ 0.62425923,  0.84241547],
#        [ 0.44621738, -0.83065171],
#        [-1.06713833, -0.25553487],
#        [-0.97811741,  0.86855714],
#        [-1.77930573, -1.22277684],
#        [ 0.71328016,  0.5025737 ],
#        [ 2.04859403,  1.20839891],
#        [-0.71105464,  1.02540719]])

# %% [markdown]
# ## training the model

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %% [markdown]
# # model training

# %%
clf.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ##evaluate the model

# %%
y_pred = clf.predict(X_test)

# %%
Y_test
# Out:
# 58    1
# 6     0
# 0     1
# 80    0
# 12    0
# 89    0
# 85    1
# 52    1
# 82    1
# 44    1
# 28    0
# 95    0
# 74    1
# 79    1
# 59    0
# 76    0
# 68    0
# 43    1
# 53    1
# 47    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test, y_pred)
# Out:
# 0.95

# %%
from mlxtend.plotting import plot_decision_regions

# %%
# Plotting decision regions
plot_decision_regions(X_train,Y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %% [markdown]
# with this lib i can execute my model in website

# %%
import pickle

# %%
pickle.dump(clf, open('model.pkl', 'wb'))
